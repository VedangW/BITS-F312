# %% [markdown]
# Q1.construct a MultiLayer Perceptron using 2 hidden layers to classify MNIST data using tensorflow

# %%
# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)

import tensorflow as tf
# Out:
# WARNING:tensorflow:From <ipython-input-1-c23211f5c157>:3: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From C:\Users\mirza914\Anaconda2\envs\torch_enc\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From C:\Users\mirza914\Anaconda2\envs\torch_enc\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
# Network Parameters
n_hidden_1 = # 1st layer number of neurons
n_hidden_2 =  # 2nd layer number of neurons
n_input = 784# MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)

# Parameters
learning_rate = 
training_epochs =
batch_size = 
display_step = 1

# %%
# tf Graph input
X = tf.placeholder("float", [None, n_input])
Y = tf.placeholder("float", [None, n_classes])

# %%
# Store layers weight & bias
weights = {
    'h1': 
    'h2': 
    'out': 
}
biases = {
    'b1': 
    'b2': 
    'out': 
}

# %%
def multilayer_perceptron(x):
    # Hidden fully connected layer with n_hidden_1 neurons
    layer_1 = 
    # Hidden fully connected layer with n_hidden_2 neurons
    layer_2 = 
    # Output fully connected layer with a neuron for each class
    out_layer =
    return out_layer

# %%
# Construct model
logits = multilayer_perceptron(X)

# Define loss and optimizer
loss_op = #use softmax_cross_entropy with logits
optimizer = #Use optimizer of choice eg.RMSprop,Adam etc
train_op = #optimizer should minimize defined loss function(loss_op)
# Initializing the variables
init =
# Out:
# WARNING:tensorflow:From <ipython-input-8-582974abf726>:6: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.

# %%
with tf.Session() as sess:
    sess.run(init)

    # Training cycle
    for epoch in range(training_epochs):
        avg_cost = 0.
        total_batch = int(mnist.train.num_examples/batch_size)
        # Loop over all batches
        for i in range(total_batch):
            batch_x, batch_y = mnist.train.next_batch(batch_size)
            # Run optimization op (backprop) and cost op (to get loss value)
            _, c = 
            # Compute average loss
            avg_cost += c / total_batch
        # Display logs per epoch step
        if epoch % display_step == 0:
            print("Epoch:", '%04d' % (epoch+1), "cost={:.9f}".format(avg_cost))
    print("Optimization Finished!")

    # Test model
    pred =   # Apply softmax to logits
    correct_prediction = #Use tf.equal to find pred and Y has the same output
    # Calculate accuracy
    accuracy = 
    print("Accuracy:", accuracy.eval({X: mnist.test.images, Y: mnist.test.labels}))
# Out:
# Epoch: 0001 cost=313.222951840
# Epoch: 0002 cost=102.831248533
# Epoch: 0003 cost=74.834444670
# Epoch: 0004 cost=58.771203648
# Epoch: 0005 cost=49.614756791
# Epoch: 0006 cost=43.524937657
# Epoch: 0007 cost=38.302999151
# Epoch: 0008 cost=34.873598113
# Epoch: 0009 cost=31.584981094
# Epoch: 0010 cost=29.019637420
# Epoch: 0011 cost=27.453704700
# Epoch: 0012 cost=25.263022909
# Epoch: 0013 cost=24.408573531
# Epoch: 0014 cost=22.868049453
# Epoch: 0015 cost=21.719891400
# Optimization Finished!
# Accuracy: 0.8916

# %% [markdown]
# Q2.Perform convolution operation on a 2D matrix.Refer to the animation given in this page under 'Architecture' to understant 2d convolution operation
# https://towardsdatascience.com/applied-deep-learning-part-4-convolutional-neural-networks-584bc134c1e2

# %%
import skimage.data  
import numpy as np
import matplotlib.pyplot as plt
# Reading the image  
img = skimage.data.chelsea()  
# Converting the image into gray.  
img = skimage.color.rgb2gray(img)

# %%
plt.imshow(img, interpolation='nearest')

# %%
kernel= np.array([[-1, -1, -1], [-1, 8, -1],[-1,-1,-1]])

# %%
def convolution2d(image, kernel, bias):
    
    return new_image

# %%
new_image=convolution2d(img,kernel,0)

# %%
plt.imshow(new_image, interpolation='nearest')
